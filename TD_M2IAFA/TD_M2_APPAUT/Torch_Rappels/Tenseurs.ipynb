# %% [markdown]
# un peu plus de détail sur la manipulation de tenseurs

# %%
import torch
from torch import nn, tensor
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
training_data = datasets.MNIST(
    root="~/Ressources/MNIST",
    train=True,
    download=True,
    transform=ToTensor(),
    #target_transform = ToTensor()
)

# %%
training_data.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
########## indexing  / mult operation

# %%
img = training_data.data[0:10]/255

# %%
img.shape
# Out:
# torch.Size([10, 28, 28])

# %%
img1 = img[0]
img1.size()
# Out:
# torch.Size([28, 28])

# %%
plt.imshow(img1)

# %%
plt.imshow(img1[::2,::2])
img1[::2,::2].size()
# Out:
# torch.Size([14, 14])

# %%
plt.imshow(img1[:14,:])

# %%
img[:,0,:20].shape
# Out:
# torch.Size([10, 20])

# %%
img[:,0:1,:20].shape
# Out:
# torch.Size([10, 1, 20])

# %%
a = img[:,0:1,:20].squeeze()
a.shape # -> enlève dimension à une seule valeur
# Out:
# torch.Size([10, 20])

# %%
a.unsqueeze(0).shape # ajoute dimension (par ex pour compatibilité avec opérations par batch)
# Out:
# torch.Size([1, 10, 20])

# %%
transfo = torch.rand(2,28)
transfo.shape
# Out:
# torch.Size([2, 28])

# %%
transfo[0]
# Out:
# tensor([0.3356, 0.6521, 0.2846, 0.1585, 0.1054, 0.4761, 0.5747, 0.6502, 0.7032,
#         0.0812, 0.0091, 0.5066, 0.0862, 0.6800, 0.7632, 0.2054, 0.9238, 0.2441,
#         0.3502, 0.3786, 0.1162, 0.9609, 0.2293, 0.4452, 0.9127, 0.5273, 0.5465,
#         0.1463])

# %%
mult = transfo@img
# ou bien: mult = transfo.matmul(img)
mult.shape
# Out:
# torch.Size([10, 2, 28])

# %%
super_batch = torch.rand(30,2,3,3,28,28)
super_out = transfo@super_batch
super_out.shape #torch.Size([30, 2, 3, 2, 28])
# Out:
# torch.Size([30, 2, 3, 3, 2, 28])

# %%
# on peut nommer les dimensions pour s'y retrouver
img.names = ("batch","width","length")

# %%
mult = transfo@img
mult.names
# Out:
# ('batch', None, 'length')

# %%
#######################################  cat / chunk / split ##############
#### exemple d'usage: faire des batchs simples

# %%
training_data.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
training_data.data.chunk(10)[0].shape
# Out:
# torch.Size([5455, 28, 28])

# %%
# couper une image en 4 bandes, dans tout le batch
training_data.data.chunk(4,dim=1)[0].shape
# Out:
# torch.Size([60000, 7, 28])

# %%
chunks = training_data.data.chunk(10)
print(len(chunks))
torch.cat(chunks).shape
# Out:
# 10
# torch.Size([60000, 28, 28])

# %%
splits = training_data.data.split(1000)
print(len(splits))
splits[0].shape
# Out:
# 60
# torch.Size([1000, 28, 28])

# %%
torch.cat(splits).shape
# Out:
# torch.Size([60000, 28, 28])

# %%
torch.cat(chunks).shape
# Out:
# torch.Size([60000, 28, 28])

# %%
torch.cat(training_data.data.chunk(10)) == training_data.data
# Out:
# tensor([[[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         ...,
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]]])

# %%
### stack / unbind 

# stack remet une liste de tenseurs en un seul tenseur en ajoutant une dimension (différent de torch.cat)
print("%s x %s"%(len(chunks),chunks[0].shape))
new_t = torch.stack(chunks)
new_t.shape
# Out:
# 10 x torch.Size([6000, 28, 28])
# torch.Size([10, 6000, 28, 28])

# %%
new_c = torch.unbind(new_t)
print(len(new_c))
print(new_c[0].shape)
# Out:
# 10
# torch.Size([6000, 28, 28])

# %%
########### view ###########

# %%
x = torch.randn(4, 4)
x.shape, x.size()
# Out:
# (torch.Size([4, 4]), torch.Size([4, 4]))

# %%
y = x.view(16)
y.shape
# Out:
# torch.Size([16])

# %%
y = x.view(8,2)
y.shape
# Out:
# torch.Size([8, 2])

# %%
y = x.view(8,-1)
y.shape
# Out:
# torch.Size([8, 2])

# %%
x.view(9,2)# ne peut pas marcher
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/qp/m4x_nf996xq9pxj7nm2t9ffr0000gn/T/ipykernel_33996/709340238.py in <cell line: 0>()
# ----> 1 x.view(9,2)# ne peut pas marcher
#
# RuntimeError: shape '[9, 2]' is invalid for input of size 16

# %%
############## exemple d'application le dataset bike #############
import numpy as np
import pandas as pds

# %%
bikes_pds = pds.read_csv("bike_hour.csv")
bikes_pds.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/qp/m4x_nf996xq9pxj7nm2t9ffr0000gn/T/ipykernel_33996/973403590.py in <cell line: 0>()
# ----> 1 bikes_pds = pds.read_csv("bike_hour.csv")
#       2 bikes_pds.head()
#
# ~/miniconda3/envs/311_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# ~/miniconda3/envs/311_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# ~/miniconda3/envs/311_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# ~/miniconda3/envs/311_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# ~/miniconda3/envs/311_env/lib/python3.11/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bike_hour.csv'

# %%
print(bikes_pds.head()[["dteday","season","yr","temp","hum","cnt"]].to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#      dteday &  season &  yr &  temp &   hum &  cnt \\
# \midrule
#  2011-01-01 &       1 &   0 &  0.24 &  0.81 &   16 \\
#  2011-01-01 &       1 &   0 &  0.22 &  0.80 &   40 \\
#  2011-01-01 &       1 &   0 &  0.22 &  0.80 &   32 \\
#  2011-01-01 &       1 &   0 &  0.24 &  0.75 &   13 \\
#  2011-01-01 &       1 &   0 &  0.24 &  0.75 &    1 \\
# \bottomrule
# \end{tabular}

# %%
bikes_numpy = np.loadtxt("bike_hour.csv", 
                         dtype=np.float32, 
                         delimiter=",", 
                         skiprows=1, 
                         converters={1: lambda x: float(x[8:10])}) # <1>
bikes = torch.from_numpy(bikes_numpy)
bikes = bikes[:17376,:]  # divisible par 24
print(bikes.shape, bikes.stride()) # → torch.Size([17376, 17]), (17, 1)
# Out:
# torch.Size([17376, 17]) (17, 1)

# %%
daily = bikes.view(-1,24,bikes.shape[1])

# %%
bikes[0,7], daily[0,:,7]
# Out:
# (tensor(6.),
#  tensor([6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6.]))

# %%
bikes[0,7] = 15
daily[0,:,7]
# Out:
# tensor([15.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,
#          6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.,  6.])

# %%
import torch
A = torch.randn(1, 2)
B = torch.randn(2, 3)

# works
C = torch.matmul(A, B)
print(C.shape)
print(C)
# torch.Size([1, 3])

# works
C = A @ B
print(C.shape)
print(C)
# torch.Size([1, 3])

# breaks
torch.matmul(B, A)
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (2x3 and 1x2)

# breaks
B @ A
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (2x3 and 1x2)
# Out:
# torch.Size([1, 3])
# tensor([[-1.7157,  0.8757, -7.7868]])
# torch.Size([1, 3])
# tensor([[-1.7157,  0.8757, -7.7868]])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 18
#      14 print(C)
#      15 # torch.Size([1, 3])
#      16
#      17 # breaks
# ---> 18 torch.matmul(B, A)
#      19 # RuntimeError: mat1 and mat2 shapes cannot be multiplied (2x3 and 1x2)
#      20
#      21 # breaks
#      22 B @ A
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (2x3 and 1x2)
